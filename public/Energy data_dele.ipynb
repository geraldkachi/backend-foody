# %%
import pandas as pd
import requests
import json
import datetime  
from dateutil.relativedelta import relativedelta

# %%
URL = "https://data-api.ammp.io/v1/token"
headers = {"x-api-key": "uHu63AMy.aUk02Y6lM0eArzq84K87z/ObSjEZPz9qEPg6dP07"}
resp = requests.post(URL, headers = headers)
resp
tk = json.loads(resp.text)['access_token']
tk
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..ixU009WtwSOe5s7aYN59rOPcz9KJHNE_0pDHNQbrIyw'

# %%
myUrl = 'https://data-api.ammp.io/v1/assets'
headers = {"Authorization": "Bearer %s" %(tk)}
response = requests.get(myUrl,headers=headers).json()
##print(requests.get(myUrl,headers=headers).json())

# %%
#extract asset_id

response = pd.DataFrame.from_dict(response)
response = response.asset_id.values.tolist()
response
# Out:
# ['a3f33826-4f88-40fc-b1d2-08be046e90aa',
#  'e1cb3d56-966c-4a5e-936d-58f264237d55',
#  '27b2cd9e-2a09-44a5-90c6-5fc5bd069551',
#  'debfdba7-2393-481d-bd2a-133d382ebbf2',
#  '67b4569c-92ac-44f8-857d-a6015bce8f7f',
#  '3ebfe159-bddd-4a56-9e9d-de08ba20f7e3',
#  '35a061af-9164-47dd-b66b-17689e78726f',
#  'a811c54c-0ca7-4f09-8592-8c4430bc33ee',
#  'ad113e1b-e526-4b93-9021-7095ed53e241',
#  'fd6b2172-eab1-4006-8097-58756481de40',
#  '224de67b-31e6-449a-93a2-46719f969a2f',
#  '51ef0c9d-110b-4bca-9d5e-22d0f39b82d0',
#  'bee27379-3efc-4905-ad66-6c9d5f11fb45',
#  '9a86aa13-6148-4c60-a4e5-6ea86394a7e4',
#  '8f863c58-7752-4cf9-bb65-da58e10fd96f',
#  '486544aa-1c2e-43d2-aedc-cf7321fe7f94',
#  'd6183465-1fde-4d6f-bbf5-44ec2dfff9d0',
#  '0381c4bb-6712-48a1-8d27-fab1db267b25',
#  'b9ff7a9b-aa29-4aa2-96c1-946338f8204d',
#  'e28ccaf4-5638-433f-94f1-9ac08c4ec555',
#  'f9a6db90-d8e1-4f3e-bc02-4c1b3e940b78',
#  'c6722045-1a5c-45b8-bbb5-bf28b83762c9',
#  '51653c75-094e-4716-8261-9db17da06a77',
# ...

# %%
# date_from = datetime.datetime.strptime('2024-05-31 4:00:00', '%Y-%m-%d %H:%M:%S')
# date_to = datetime.datetime.strptime('2024-05-31 19:00:00', '%Y-%m-%d %H:%M:%S')

Date_sequence_start= ['2024-05-1 0:00:00','2024-05-31 0:00:00','2024-05-2 0:00:00','2024-05-3 0:00:00','2024-05-4 0:00:00','2024-05-5 0:00:00','2024-05-6 0:00:00','2024-05-7 0:00:00','2024-05-8 0:00:00','2024-05-9 0:00:00','2024-05-10 0:00:00',
               '2024-05-11 0:00:00','2024-05-12 0:00:00','2024-05-13 0:00:00','2024-05-14 0:00:00','2024-05-15 0:00:00','2024-05-16 0:00:00','2024-05-17 0:00:00','2024-05-18 0:00:00','2024-05-19 0:00:00','2024-05-20 0:00:00','2024-05-21 0:00:00',
               '2024-05-22 0:00:00','2024-05-23 0:00:00','2024-05-24 0:00:00','2024-05-25 0:00:00','2024-05-26 0:00:00','2024-05-27 0:00:00','2024-05-28 0:00:00','2024-05-29 0:00:00','2024-05-30 0:00:00','2024-05-31 0:00:00']

# Define the range of days in June
start_day = 1
end_day = 13

# Define the list of asset IDs
asset_ids = response
# asset_ids = ['67b4569c-92ac-44f8-857d-a6015bce8f7f', '67b4569c-92ac-44f8-857d-a6015bce8f7f']

# Dictionary to store the results
results = {}

# List to store the results as dictionaries
data_list = []

# Loop through each day in the range
for day in range(start_day, end_day + 1):
    date_from = datetime.datetime.strptime(f'2024-06-{day:02d} 00:00:00', '%Y-%m-%d %H:%M:%S')
    date_to = datetime.datetime.strptime(f'2024-06-{day:02d} 23:59:59', '%Y-%m-%d %H:%M:%S')
    
    # Loop through each asset ID
    for asset_id in asset_ids:
        params = {
            'date_from': date_from.isoformat(),
            'date_to': date_to.isoformat(),
            'interval': '1d'
        }
        headers = {"Authorization": f"Bearer {tk}"}
        
        # Fetch the data
        response = requests.get(f'https://data-api.ammp.io/v1/assets/{asset_id}/historic-energy', headers=headers, params=params)

         # Check if the response is successful
        if response.status_code == 200:
            try:
                data = response.json()
                
                # Ensure data is a list of dictionaries
                if isinstance(data, dict):
                    data = [data]
                
                # Append each record to the data list
                for record in data:
                    record['asset_id'] = asset_id
                    record['date'] = f'2024-06-{day:02d}'
                    data_list.append(record)
            except ValueError:
                print(f"Response content is not valid JSON: {response.content}")
        else:
            print(f"Failed to fetch data for asset {asset_id} on 2024-06-{day:02d}: {response.status_code}")

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(data_list)

# Print the DataFrame
print(df)

# date_from = datetime.datetime.strptime('2024-05-31 0:00:00', '%Y-%m-%d %H:%M:%S')
# date_to = datetime.datetime.strptime('2024-05-31 23:59:59', '%Y-%m-%d %H:%M:%S')

# params = {'date_from': date_from , 'date_to': date_to, 'interval': '1d' }
# headers = {"Authorization": "Bearer %s" %(tk)}
# response = requests.get('https://data-api.ammp.io/v1/assets/67b4569c-92ac-44f8-857d-a6015bce8f7f/historic-energy',
#         headers=headers,params=params).json()
# Out:
# Failed to fetch data for asset b'{"asset_id":"a3f33826-4f88-40fc-b1d2-08be046e90aa","asset_name":"JRM_LAG_001","long_name":"Jara Mall Ikeja","latitude":6.592369,' on 2024-06-01: 422
# Failed to fetch data for asset b'"longitude":3.338317,"total_pv_power":150000.0,"region":"South-West","place":"Ikeja","country_code":"NG","beta":null,"tref":null' on 2024-06-01: 422
# Failed to fetch data for asset b',"tags":{"field_service_engineer":"Matthew Ogunkunle"},"pv_energy":{"interval":"1d","data":[{"date":"2024-06-01","value":416287.' on 2024-06-01: 422
# Failed to fetch data for asset b'0}],"data_provider":["sma"],"unit":"Wh"},"consumption_energy":{"interval":"1d","data":[{"date":"2024-06-01","value":1364983.0}],' on 2024-06-01: 422
# Failed to fetch data for asset b'"data_provider":["sma"],"unit":"Wh"},"external_energy":{"interval":"1d","data":[{"date":"2024-06-01","value":950112.0}],"data_pr' on 2024-06-01: 422
# ...

# %%
response
# Out:
# <Response [200]>

# %%
# DataF = pd.json_normalize(response, record_path=[['pv_power','data']], meta=[
#                   'asset_id', 'asset_name'])
response_data = response              

    
energy_params = ['pv_energy', 'consumption_energy','external_energy', 'energy_to_grid',
                 'battery_charge_energy', 'battery_discharge_energy', 'genset_energy']

# Create a dictionary to store parameter values
param_values = {}

# Extract data values from each energy parameter
max_length = max(len(response_data[param]['data']) for param in energy_params if response_data[param]['data'])
max_length
# Find the first parameter that contains data and extract the date
for param in energy_params:
    data = response_data[param]['data']
    if data:
        date_values = [entry['date'] if entry else None for entry in response_data['pv_energy']['data']] + [None] * (max_length - len(data))
        param_values['date'] = date_values
        break        



for param in energy_params:
    data = response_data[param]['data']
    values = [entry['value'] if entry else None for entry in data] + [None] * (max_length - len(data))
    param_values[param] = values
#     date_values = [entry['date'] if entry else None for entry in response_data['pv_power']['data']] + [None] * (max_length - len(data))
#     param_values['date'] = date_values


        
# Convert the dictionary to a DataFrame
DataF = pd.DataFrame(param_values)

# Add 'asset_id' and 'asset_name' to the DataFrame
DataF['asset_id'] = response_data['asset_id']
DataF['asset_name'] = response_data['asset_name']

# Reorder columns
columns_order = ['date','asset_id', 'asset_name'] + energy_params
DataF = DataF[columns_order]

# Now DataF contains extracted data with each parameter as a column
DataF
# Out:
#          date                              asset_id     asset_name  pv_energy  \
# 0  2024-05-31  67b4569c-92ac-44f8-857d-a6015bce8f7f  STB_LAG_001_A    27726.0
#
#    consumption_energy  external_energy  energy_to_grid battery_charge_energy  \
# 0            211562.0         183836.0             0.0                  None
#
#   battery_discharge_energy  genset_energy
# 0                     None            0.0

# %%
# response_data = response

# # Specify the paths to your parameters
# paths = [['consumption_power', 'data'], ['pv_power', 'data']]

# # Initialize an empty list to store DataFrames
# dfs = []

# # Iterate over the paths and normalize the data
# for path in paths:
#     df = pd.json_normalize(response_data, record_path=path, meta=['asset_id', 'asset_name'])
#     dfs.append(df)

# # Merge the DataFrames on common columns
# DataF = dfs[0]  # Start with the first DataFrame
# for df in dfs[1:]:  # Iterate over the rest of the DataFrames
#     DataF = pd.merge(DataF, df, on=['asset_id', 'asset_name'], how='inner')

# %%
# DataF

# %%
# values = [10,10,10] + [None] * (10)
# values
